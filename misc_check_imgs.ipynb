# %%
import os
import matplotlib.pyplot as plt
import cv2

img_dir = './Dataset/faces/homography_thr_train_warped'
for i in range(5):
    im = cv2.imread(os.path.join(img_dir, os.listdir(img_dir)[i]))
    im = cv2.cvtColor(im, cv2.COLOR_RGB2BGR)
    plt.imshow(im)
    plt.show()
